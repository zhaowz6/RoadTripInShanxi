# %%
import csv
import pandas as pd

# %%
data=pd.read_csv('山西旅游景点.csv',encoding='gbk')

# %%
# Out:
#             景区    星级         地区              地址   评分     价格           简介  \
# 0          五台山  5A景区  山西·忻州·五台县    山西省忻州市五台县台怀镇  4.9  115.0   中国佛教四大名山之首
# 1         云冈石窟  5A景区  山西·大同·南郊区  山西省大同市云冈区云冈镇1号  5.0  100.0     中国三大石窟之一
# 2        晋祠博物馆  4A景区  山西·太原·晋源区  山西省太原市晋源区晋祠公园内  5.0   80.0    晋国宗祠园林建筑群
# 3         应县木塔  4A景区   山西·朔州·应县   山西省朔州市应县应元街1号  5.0   48.0  辽代古建筑，由木头建成
# 4  山西黄河壶口瀑布旅游区  5A景区   山西·临汾·吉县  山西省临汾市吉县壶口镇延壶路  4.9   90.0   看滚滚黄河水呼啸而下
#
#                                                  详情页
# 0  https://piao.qunar.com/ticket/detail_286940196...
# 1  https://piao.qunar.com/ticket/detail_346725629...
# 2  https://piao.qunar.com/ticket/detail_374810364...
# 3  https://piao.qunar.com/ticket/detail_319454897...
# 4  https://piao.qunar.com/ticket/detail_292119061...

# %%
data.head()

# %%
data_f=data.dropna(subset=['星级'],inplace=True)

# %%
data.tail()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35 entries, 0 to 238
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   景区      35 non-null     object
#  1   星级      35 non-null     object
#  2   地区      35 non-null     object
#  3   地址      35 non-null     object
#  4   评分      32 non-null     float64
#  5   价格      28 non-null     float64
#  6   简介      33 non-null     object
#  7   详情页     35 non-null     object
# dtypes: float64(2), object(6)
# memory usage: 2.5+ KB

# %%
index=data[data['评分'].isnull()]
index
# Out:
#            景区    星级         地区                    地址  评分  价格           简介  \
# 60      赵杲观景区  3A景区   山西·忻州·代县  忻州市代县城外约23公里处的天台山沟掌里 NaN NaN          NaN
# 110   青草坡乡村庄园  3A景区  山西·太原·阳曲县          太原市阳曲县黄寨镇上安村 NaN NaN  住宿在特色的窑洞四合院
# 143  中太行洗耳河景区  4A景区  山西·长治·黎城县       山西省长治市黎城县西井镇彭庄村 NaN NaN          NaN
#
#                                                    详情页
# 60   https://piao.qunar.com/ticket/detail_954008192...
# 110  https://piao.qunar.com/ticket/detail_330775639...
# 143  https://piao.qunar.com/ticket/detail_252544505...

# %%
data['评分'] = data['评分'].fillna('4.7')

# %%
data['价格']=data['价格'].fillna('10')

# %%
data.to_csv('A级景区评分价格.csv')
